# %%
import numpy
import glob

m1l_dir = ['../Data/AWS_m1.large_R1/Part1/',
    '../Data/AWS_m1.large_R1/Part2/',
    '../Data/AWS_m1.large_R1/Part3/',
    '../Data/AWS_m1.large_R1/Part5/']

m2xl_dir = ['../Data/AWS_m2.xlarge/Part1/',
    '../Data/AWS_m2.xlarge/Part2/',
    '../Data/AWS_m2.xlarge/Part3/',
    '../Data/AWS_m2.xlarge/Part5/']

oth1_dir = ['../Data/Other_source_32gb_R2/Part1/',
    '../Data/Other_source_32gb_R2/Part2/',
    '../Data/Other_source_32gb_R2/Part3/',
    '../Data/Other_source_32gb_R2/Part5/']

names = ['Trimming', 'Diginorm', 'Assembly', 'Annotation']
# note: different zones!

def _get_max_resident(filename):
    for line in open(filename):
        line = line.rstrip()
        if 'system' in line:
            fields1 = line.split('user')
            user = float(fields1[0])
            fields1b = line.split('system')[0].split()[-1]
            system = float(fields1b)
            walltime = line.split('elapsed')[0].split()[-1]
            walltime = walltime.split(':')
            assert len(walltime)<=3
            if (len(walltime) == 3):
                hours = float(walltime[0])
                minutes = float(walltime[1])
                seconds = float(walltime[2])
            else:
                hours = float(0)
                minutes = float(walltime[0])
                seconds = float(walltime[1])
            wall_seconds = hours*60*60 + minutes*60 + float(seconds)
            return float(system), float(user), float(wall_seconds)
    raise Exception(filename)

file_names = {}
file_names['Part1'] =[]
file_names['Part2'] =[]
file_names['Part3'] =[]
file_names['Part5'] =[]

file_names['Part1']  = glob.glob(datadirs[0] + '*')
file_names['Part2']  = glob.glob(datadirs[1] + '*')
file_names['Part3']  = glob.glob(datadirs[2] + '*')
file_names['Part5'] = glob.glob(datadirs[3] + '*')

# %%
file_stats = {}
file_stats['Part1'] ={}
file_stats['Part2'] ={}
file_stats['Part3'] ={}
file_stats['Part5'] ={}

for key in file_names:
    print key

# %%
for key in file_names:
    for filename in file_names[key]:
        file_stats[key][filename] = {}
        for line in open(filename):
                line = line.rstrip()
                if 'system' in line:
                    line = line.split('system')
                    line = line[1].split('elapsed')
                    file_stats[key][filename]['time'] = line[0].split(' ')[1]
                    line = line[1].split('%CPU')
                    
                    file_stats[key][filename]['cpu_usage'] = line[0].split(' ')[1]
                    line = line[1].split('avgdata')
                    line = line[1].split('maxresident')
                    file_stats[key][filename]['memory'] = line[0].split(' ')[1]
                elif 'outputs' in line:
                    line = line.split('inputs')
                    file_stats[key][filename]['inputs']= line[0]
                    line = line[1].split('outputs')
                    file_stats[key][filename]['outputs'] = line[0].split('+')[1]
                    
                    line = line[1].split('major')
                    file_stats[key][filename]['major'] = line[0].split(' (')[1]
                    
                    line = line[1].split('minor')
                    file_stats[key][filename]['minor'] = line[0].split('+')[1]

# %%
file_stats
# Out:
# {'Part1': {'../Data/AWS_m2.xlarge/Part1/adapter_trim.time': {'cpu_usage': '1',
#    'inputs': '7656',
#    'major': '11',
#    'memory': '20000',
#    'minor': '1380',
#    'outputs': '32',
#    'time': '0:02.86'},
#   '../Data/AWS_m2.xlarge/Part1/extract_pairs.sh.time': {'cpu_usage': '98',
#    'inputs': '28547792',
#    'major': '97',
#    'memory': '27408',
#    'minor': '69702',
#    'outputs': '105115984',
#    'time': '2:56:45'},
#   '../Data/AWS_m2.xlarge/Part1/quality_trim.sh.time': {'cpu_usage': '143',
#    'inputs': '30869616',
#    'major': '17',
#    'memory': '6288',
#    'minor': '116830',
#    'outputs': '29096592',
#    'time': '6:11:11'},
#   '../Data/AWS_m2.xlarge/Part1/trim_clean.sh.time': {'cpu_usage': '97',
#    'inputs': '105887408',
#    'major': '25',
#    'memory': '6448',
#    'minor': '99878',
#    'outputs': '35071480',
#    'time': '2:27:57'},
#   '../Data/AWS_m2.xlarge/Part1/trim_run.sh.time': {'cpu_usage': '120',
#    'inputs': '42321920',
#    'major': '187',
#    'memory': '356944',
#    'minor': '1184875',
#    'outputs': '148782376',
#    'time': '7:00:54'}},
#  'Part2': {'../Data/AWS_m2.xlarge/Part2/diginorm_pe.sh.time': {'cpu_usage': '99',
#    'inputs': '28373240',
#    'major': '37',
#    'memory': '46909232',
#    'minor': '2932144',
#    'outputs': '32782840',
#    'time': '4:51:58'},
#   '../Data/AWS_m2.xlarge/Part2/diginorm_se.time': {'cpu_usage': '87',
#    'inputs': '25088016',
#    'major': '44',
#    'memory': '46905456',
#    'minor': '2931962',
#    'outputs': '23787576',
#    'time': '18:01.64'},
#   '../Data/AWS_m2.xlarge/Part2/filter-adund.time': {'cpu_usage': '113',
#    'inputs': '33147376',
#    'major': '39',
#    'memory': '46924160',
#    'minor': '2937412',
#    'outputs': '7685776',
#    'time': '36:24.91'}},
#  'Part3': {'../Data/AWS_m2.xlarge/Part3/trinity.time': {'cpu_usage': '189',
#    'inputs': '22499168',
#    'major': '387',
#    'memory': '56228144',
#    'minor': '3786570457',
#    'outputs': '89073992',
#    'time': '23:18:37'},
#   '../Data/AWS_m2.xlarge/Part3/trinity_split.sh.time': {'cpu_usage': '91',
#    'inputs': '2368528',
#    'major': '21',
#    'memory': '27360',
#    'minor': '65763',
#    'outputs': '13584832',
#    'time': '7:50.47'}},
#  'Part5': {'../Data/AWS_m2.xlarge/Part5/annotate.time': {'cpu_usage': '94',
#    'inputs': '605544',
#    'major': '23',
#    'memory': '388704',
#    'minor': '27567',
#    'outputs': '592128',
#    'time': '0:14.37'},
#   '../Data/AWS_m2.xlarge/Part5/format_annotate.sh.time': {'cpu_usage': '194',
#    'inputs': '600416',
#    'major': '114',
#    'memory': '566016',
#    'minor': '135439784',
#    'outputs': '3110096',
#    'time': '36:16:32'},
#   '../Data/AWS_m2.xlarge/Part5/get_mouse_info.sh.time': {'cpu_usage': '51',
#    'inputs': '44280',
#    'major': '25',
#    'memory': '119856',
#    'minor': '16247',
#    'outputs': '58152',
#    'time': '0:04.08'},
#   '../Data/AWS_m2.xlarge/Part5/group.time': {'cpu_usage': '98',
#    'inputs': '8848',
#    'major': '19',
#    'memory': '96032',
#    'minor': '6403',
#    'outputs': '50248',
#    'time': '1:18.20'},
#   '../Data/AWS_m2.xlarge/Part5/homology.time': {'cpu_usage': '96',
#    'inputs': '2242784',
#    'major': '14',
#    'memory': '415936',
#    'minor': '28705',
#    'outputs': '19016',
#    'time': '1:53.49'},
#   '../Data/AWS_m2.xlarge/Part5/khmer_part.time': {'cpu_usage': '136',
#    'inputs': '104384',
#    'major': '30',
#    'memory': '3547952',
#    'minor': '384352',
#    'outputs': '725552',
#    'time': '6:29.76'},
#   '../Data/AWS_m2.xlarge/Part5/mouse.x.nema.time': {'cpu_usage': '193',
#    'inputs': '246016',
#    'major': '458',
#    'memory': '564640',
#    'minor': '14350027',
#    'outputs': '473864',
#    'time': '13:21:12'},
#   '../Data/AWS_m2.xlarge/Part5/nema.x.mouse.time': {'cpu_usage': '194',
#    'inputs': '628512',
#    'major': '179',
#    'memory': '211904',
#    'minor': '121849750',
#    'outputs': '2251712',
#    'time': '22:58:21'},
#   '../Data/AWS_m2.xlarge/Part5/orthology.time': {'cpu_usage': '96',
#    'inputs': '2711464',
#    'major': '15',
#    'memory': '471648',
#    'minor': '33173',
#    'outputs': '25808',
#    'time': '2:06.02'}}}

# %%
        if 'system' in line:
            fields1 = line.split('user')
            user = float(fields1[0])
            fields1b = line.split('system')[0].split()[-1]
            system = float(fields1b)
            walltime = line.split('elapsed')[0].split()[-1]
            walltime = walltime.split(':')
            assert len(walltime)<=3
            if (len(walltime) == 3):
                hours = float(walltime[0])
                minutes = float(walltime[1])
                seconds = float(walltime[2])
            else:
                hours = float(0)
                minutes = float(walltime[0])
                seconds = float(walltime[1])
            wall_seconds = hours*60*60 + minutes*60 + float(seconds)
